# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Certain state governments in the United States administer either the SAT or the ACT exclusively and also cover the fees for taking the test. These programs increase access to low-income students and consequently the participation rate of both standardized tests. However, there remains pocket of demands to take the non-mandatory standardized test in the state to expand the student's options for colleges.
#
# This project attempts to answer the following questions:
#
# 1. Establish if there is any relationship between the test performance and test participation rate for both SAT and ACT.
#
# 2. Identify the SAT-mandatory states that has high demand for the ACT test
#
# 3. Identify states with low ACT participation rate from states without test requirement
#
# These information would be useful for ACT to draw useful lessons from states with the high participation and to apply them and devote more resources in states with low participation rate.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Due to the federal system of the United States, each state is free to make its own requirement with regards to the college admission tests. Some states may choose to make either the ACT or the SAT compulsory, or even give the student to choose between these two tests. Furthermore,  certain states may choose to make the test free of charge for the students to remove the barrier of access for low-income students. There are also states where taking either tests are not mandatory. Students in these states would also need to pay for the tests out of their pocket ([*source*](https://magoosh.com/hs/sat/states-that-require-the-act-or-sat/)).
#
# Other initiatives to make the testing accessible includes SAT School Days which allows schools to offer the SAT to students during the week, generally for free. Instead of traveling to a testing location on a Saturday morning, students whose schools participate in SAT School Day get to take an official SAT at their own school, during class time. This means they don’t need to worry about transportation or scheduling issues that might otherwise prevent them from taking the SAT ([*source*](https://blog.prepscholar.com/sat-school-day)).
#
# All the factors above influence both the participation rates and the performance both tests across the states.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# ### Dataset Chosen
#
# The following datasets were used for this project:
#
# * [`act_2017.csv`](./data/act_2017.csv): Dataset containing ACT English, Math, Reading and Composite Scores and Participation Rate by State in 2017
# * [`act_2018.csv`](./data/act_2018.csv): Dataset containing ACT Composite Scores and Participation Rate by State in 2018
# * [`sat_2017.csv`](./data/sat_2017.csv): Dataset containing SAT Evidence-Based Reading and Writing, Math and Total Scores and Participation Rate by State in 2017
# * [`sat_2018.csv`](./data/sat_2018.csv): Dataset containing SAT Evidence-Based Reading and Writing, Math and Total Scores and Participation Rate by State in 2018

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# As of May 2017, the following are the states' testing requirement:([*source*](https://magoosh.com/hs/sat/states-that-require-the-act-or-sat/))
#
# * There are 14 states that require the ACT: Alabama, Hawaii, Kentucky, Louisiana, Mississippi, Missouri, Montana, Nebraska, Nevada, North Carolina, South Carolina, Utah, Wisconsin and Wyoming.
#
#
# * There are 8 states/regions that require the SAT: Colorado, Connecticut, Delaware, District of Columbia, Illinois, Maine, Michigan and New Hampshire.
#
#
# * Idaho, Ohio, and Tennessee require a test as part of the graduation process, but these states allow you to choose the SAT or the ACT.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %% [markdown]
# #### Function Definition

# %%
def cal_mean(num_list):
    return sum(num_list)/len(num_list)

# %% [markdown]
# #### Testing the Function

# %%
num=[1,2,3,4,5,6]

cal_mean(num)
# Out:
# 3.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %% [markdown]
# #### Function Definition

# %%
def cal_sd(num_list):
    return (sum([(x - cal_mean(num_list))**2 for x in num_list])/len(num_list))**(1/2)

# %% [markdown]
# #### Testing the Function

# %%
cal_sd(num)
# Out:
# 1.707825127659933

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %% [markdown]
# #### Function Definition

# %%
def clean_string(pct):
    return float(pct.replace('%',''))/100

# %% [markdown]
# #### Testing the Function

# %%
clean_string('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# #### Importing the data for all 4 datasets

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %% [markdown]
# ### Data Cleaning for `sat_2017`

# %% [markdown]
# #### Inspect the data for `sat_2017`

# %%
# First 5 rows of the sat_2017 DataFrame
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# #### Inspect the dtype and checking for null values on `sat_2017`

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# **Key Observations:**
# 1. No null values
# 2. Participation dtype should be in float rather than object

# %% [markdown]
# #### Identify rows with errors in `sat_2017`

# %%
# Create a new column 'Total_ERW _Math' which is the sum of 'Evidence-Based Reading and Writing' and 'Math'
sat_2017['Total_ERW_Math'] = sat_2017['Evidence-Based Reading and Writing']+sat_2017['Math']

#Identify rows where the sum of 'Evidence-Based Reading and Writing' and 'Math' is not equal to 'Total'
sat_2017[(sat_2017['Total_ERW_Math']!=sat_2017['Total'])]
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 6     Connecticut          100%                                 530   512
# 7        Delaware          100%                                 503   492
# 12          Idaho           93%                                 513   493
# 15           Iowa            2%                                 641   635
# 18      Louisiana            4%                                 611   586
# 20       Maryland           69%                                 536    52
# 21  Massachusetts           76%                                 555   551
# 22       Michigan          100%                                 509   495
# 24    Mississippi            2%                                 634   607
# 27       Nebraska            3%                                 629   625
# 32       New York           67%                                 528   523
# 35           Ohio           12%                                 578   570
# ...

# %% [markdown]
# **Key Observations:**
# 1. Most of the rows has `Total_ERW_Math` which only differs with `Total` by only +/-1. It is safe to assume the `Math` and `ERW` score are correct and use them to compute the `Total` when fixing errors
# 2. Only the `Math` score in Maryland was beyond the expected range

# %% [markdown]
# #### Fix the errors observed on `sat_2017`

# %%
#Fix the error for Math Score for Maryland by minusing off the 'Evidence-Based Reading and Writing' 
#score from the 'Total' score 
sat_2017.loc[20,'Math']= sat_2017.loc[20,'Total'] - sat_2017.loc[20,'Evidence-Based Reading and Writing']

#Fix the error on Total by assuming the 'Math' and 'ERW' score are correct and use the sum to compute the 'Total'
sat_2017['Total'] = sat_2017['Evidence-Based Reading and Writing']+sat_2017['Math']

#Delete the column 'Total_ERW_Math' used for chekcing errors in the previous cell
sat_2017.drop(columns=['Total_ERW_Math'], inplace=True)

# Inspect the sat_2017 DataFrame
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# #### Change values in `Participation` to float between 0 and 1

# %%
# Use the clean_string function defined above on the sat_2017['Participation'] column using .apply
sat_2017['Participation'] = sat_2017['Participation'].apply(clean_string)
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %% [markdown]
# #### Format the string in `State` using `str.title()` to prepare for merging of DataFrame later

# %%
#Capitalize first letter of string for state
sat_2017['State'] = sat_2017['State'].apply(str.title)

# %% [markdown]
# #### Rename the columns to lower-case and replace space with underscore

# %%
#Use the pandas rename method by passing in a dictionary of before and after column names
sat_2017.rename(columns={'State': 'state',
                         'Participation': 'sat_17_participation',
                         'Evidence-Based Reading and Writing': 'sat_17_erw',
                         'Math': 'sat_17_math',
                         'Total': 'sat_17_total'
                        }, inplace=True)
sat_2017.head()
# Out:
#         state  sat_17_participation  sat_17_erw  sat_17_math  sat_17_total
# 0     Alabama                  0.05         593          572          1165
# 1      Alaska                  0.38         547          533          1080
# 2     Arizona                  0.30         563          553          1116
# 3    Arkansas                  0.03         614          594          1208
# 4  California                  0.53         531          524          1055

# %% [markdown]
# #### Check for duplicated rows and remove them as necessary

# %%
#Filter the rows which are duplicated
sat_2017[sat_2017.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, sat_17_participation, sat_17_erw, sat_17_math, sat_17_total]
# Index: []

# %% [markdown]
# #### Data Cleaning completed for sat_2017

# %%
sat_2017.head()
# Out:
#         state  sat_17_participation  sat_17_erw  sat_17_math  sat_17_total
# 0     Alabama                  0.05         593          572          1165
# 1      Alaska                  0.38         547          533          1080
# 2     Arizona                  0.30         563          553          1116
# 3    Arkansas                  0.03         614          594          1208
# 4  California                  0.53         531          524          1055

# %% [markdown]
# ### Data Cleaning for` sat_2018`

# %% [markdown]
# #### Inspect the data for `sat_2018`

# %%
# First 5 rows of the sat_2018 DataFrame
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %% [markdown]
# #### Inspect the dtype and checking for null values on `sat_2018`

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# **Key Observations:**
#
# 1. No null values
# 2. Participation dtype should be in float rather than object

# %% [markdown]
# #### Identify rows with errors in `sat_2018`

# %%
# Create a new column 'Total_ERW _Math' which is the sum of 'Evidence-Based Reading and Writing' and 'Math'
sat_2018['Total_ERW_Math'] = sat_2018['Evidence-Based Reading and Writing']+sat_2018['Math']

#Identify rows where the sum of 'Evidence-Based Reading and Writing' and 'Math' is not equal to 'Total'
sat_2018[(sat_2018['Total_ERW_Math']!=sat_2018['Total'])]
# Out:
#              State Participation  Evidence-Based Reading and Writing  Math  \
# 3         Arkansas            5%                                 592   576
# 6      Connecticut          100%                                 535   519
# 7         Delaware          100%                                 505   492
# 16          Kansas            4%                                 633   631
# 22        Michigan          100%                                 511   499
# 31      New Mexico           16%                                 552   540
# 33  North Carolina           52%                                 554   543
# 45         Vermont           64%                                 565   554
# 50         Wyoming            3%                                 633   625
#
#     Total  Total_ERW_Math
# 3    1169            1168
# 6    1053            1054
# 7     998             997
# 16   1265            1264
# 22   1011            1010
# 31   1093            1092
# 33   1098            1097
# ...

# %% [markdown]
# **Key Observations:**
#
# 1. Most of the rows has `Total_ERW_Math` which only differs with `Total` by only +/-1. It is safe to assume the `Math` and `Evidence-Based Reading and Writing` score are correct and use them to compute the `Total` when fixing errors

# %% [markdown]
# #### Fix the errors observed on `sat_2018`

# %%
#Fix the error on Total by assuming the 'Math' and 'ERW' score are correct and use the sum to compute the 'Total'
sat_2018['Total'] = sat_2018['Total_ERW_Math']

#Delete the column 'Total_ERW_Math' used for checking errors in the previous cell
sat_2018.drop(columns=['Total_ERW_Math'], inplace=True)

# Inspect the sat_2017 DataFrame
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1168
# 4  California           60%                                 540   536   1076

# %% [markdown]
# #### Change values in `Participation` to float between 0 and 1

# %%
# Use the clean_string function defined above on the sat_2018['Participation'] column using .apply
sat_2018['Participation'] = sat_2018['Participation'].apply(clean_string)
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1168
# 4  California           0.60                                 540   536   1076

# %% [markdown]
# #### Format the string in `State` using `str.title()` to prepare for merging of DataFrame later

# %%
#Capitalize first letter of string for state
sat_2018['State'] = sat_2018['State'].apply(str.title)

# %% [markdown]
# #### Rename the columns to lower-case and replace space with underscore

# %%
#Use the pandas rename method by passing in a dictionary of before and after column names
sat_2018.rename(columns={'State': 'state',
                         'Participation': 'sat_18_participation',
                         'Evidence-Based Reading and Writing': 'sat_18_erw',
                         'Math': 'sat_18_math',
                         'Total': 'sat_18_total'
                        }, inplace=True)
sat_2018.head()
# Out:
#         state  sat_18_participation  sat_18_erw  sat_18_math  sat_18_total
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1168
# 4  California                  0.60         540          536          1076

# %% [markdown]
# #### Check for duplicated rows and remove them as necessary

# %%
#Filter the rows which are duplicated
sat_2018[sat_2018.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, sat_18_participation, sat_18_erw, sat_18_math, sat_18_total]
# Index: []

# %% [markdown]
# #### Data Cleaning completed for `sat_2018`

# %%
sat_2018.head()
# Out:
#         state  sat_18_participation  sat_18_erw  sat_18_math  sat_18_total
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1168
# 4  California                  0.60         540          536          1076

# %% [markdown]
# ### Data Cleaning for `act_2017`

# %% [markdown]
# #### Inspect the data for `act_2017`

# %%
# First 5 rows of the act_2017 DataFrame
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# #### Inspect the dtype and checking for null values on `act_2017`

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# **Key Observations:**
#
# 1. Composite dtype should float64, but it is an object
# 2. Participation dtype should be in float rather than object

# %% [markdown]
# #### Identify rows with errors in `act_2017`

# %%
# Check for each subject whether they are outside the range of 0 to 36
print(act_2017[(act_2017['English']<0)|(act_2017['English']>36)])
print(act_2017[(act_2017['Math']<0)|(act_2017['Math']>36)])
print(act_2017[(act_2017['Reading']<0)|(act_2017['Reading']>36)])
print(act_2017[(act_2017['Science']<0)|(act_2017['Science']>36)])
# Out:
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []

# %% [markdown]
# **Key Observations:**
#
# 1. All scores for `English`, `Math`, `Reading` and `Science` are within the normal range of 0 to 36

# %% [markdown]
# #### Check what is causing `Composite` column to be encoded as a string?

# %%
for score in act_2017['Composite']:
    print(type(score), score)
# Out:
# <class 'str'> 21.0
# <class 'str'> 19.2
# <class 'str'> 19.8
# <class 'str'> 19.7
# <class 'str'> 19.4
# <class 'str'> 22.8
# <class 'str'> 20.8
# <class 'str'> 25.2
# <class 'str'> 24.1
# <class 'str'> 24.2
# <class 'str'> 19.8
# <class 'str'> 21.4
# <class 'str'> 19.0
# <class 'str'> 22.3
# <class 'str'> 21.4
# <class 'str'> 22.6
# <class 'str'> 21.9
# <class 'str'> 21.7
# <class 'str'> 20.0
# <class 'str'> 19.5
# <class 'str'> 24.3
# <class 'str'> 23.6
# <class 'str'> 25.4
# <class 'str'> 24.1
# <class 'str'> 21.5
# <class 'str'> 18.6
# <class 'str'> 20.4
# <class 'str'> 20.3
# <class 'str'> 21.4
# <class 'str'> 17.8
# <class 'str'> 25.5
# <class 'str'> 23.9
# <class 'str'> 19.7
# <class 'str'> 24.2
# <class 'str'> 19.1
# <class 'str'> 20.3
# <class 'str'> 22.0
# <class 'str'> 19.4
# <class 'str'> 21.8
# <class 'str'> 23.7
# <class 'str'> 24.0
# <class 'str'> 18.7
# <class 'str'> 21.8
# <class 'str'> 19.8
# <class 'str'> 20.7
# <class 'str'> 20.3
# <class 'str'> 23.6
# ...

# %% [markdown]
# **Key Observation:**
# 1. All values in `Composite` column are strings
# 2. One of the value 20.2 in the last row has an x behind

# %% [markdown]
# #### Fix the errors observed on `act_2017`

# %%
#Replace the errorneous value '20.2x' with the correct value 20.2
act_2017.loc[(act_2017['Composite']=='20.2x'), 'Composite'] = 20.2

#Convert all values in the column from string to float
act_2017['Composite'] = act_2017['Composite'].map(lambda x: float(x))

act_2017.info()

act_2017.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB
#             State Participation  English  Math  Reading  Science  Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5       23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0       21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5       20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9       20.5
# ...

# %% [markdown]
# #### Check if average of `English`, `Math`, `Reading` and `Science` is equal to `Composite` in `act_2017`

# %%
# Create a new column 'Composite_cal' which is the average of 'English', 'Math', 'Reading' and 'Science'
act_2017['Composite_cal'] = cal_mean([act_2017['English'],act_2017['Math'],act_2017['Reading'],act_2017['Science']])

#Identify rows where the average of 'English', 'Math', 'Reading' and 'Science' is not equal to 'Composite'
act_2017[(act_2017['Composite_cal']!=act_2017['Composite'])]
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# **Key Observations:**
#
# 1. The `Science` score for Maryland looks lower than normal. This resulted in Maryland's `Composite_cal` being much lower than its `Composite` score
# 2. Most of the other rows has `Composite_cal`' which only differs with `Composite` by only +/-0.2. It is safe to assume the `English`, `Math`, `Reading` and `Science` scores are correct and use them to compute the `Composite` when fixing errors

# %% [markdown]
# #### Fix the errors observed on `act_2017`

# %%
#Fix the error for 'Science' Score for Maryland by working backwards from the 'Composite' Score
act_2017.loc[21, 'Science'] = act_2017.loc[21, 'Composite']*4 - (act_2017.loc[21, 'English']+
                                                                 act_2017.loc[21, 'Math']+
                                                                 act_2017.loc[21, 'Reading'])
#Fix the error on Total by assuming the 'English', 'Math', 'Science' and Reading' score are correct
# and use the average to compute the 'Composite'
act_2017['Composite'] = cal_mean([act_2017['English'],act_2017['Math'],act_2017['Reading'],act_2017['Science']])


#Delete the column 'Composite_cal' used for checking errors in the previous cell
act_2017.drop(columns=['Composite_cal'], inplace=True)

# Inspect the act_2017 DataFrame
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 0  National           60%     20.3  20.7     21.4     21.0     20.850
# 1   Alabama          100%     18.9  18.4     19.7     19.4     19.100
# 2    Alaska           65%     18.7  19.8     20.4     19.9     19.700
# 3   Arizona           62%     18.6  19.8     20.1     19.8     19.575
# 4  Arkansas          100%     18.9  19.0     19.7     19.5     19.275

# %% [markdown]
# #### Change values in `Participation` to float between 0 and 1

# %%
# Use the clean_string function defined above on the act_2017['Participation'] column using .apply
act_2017['Participation'] = act_2017['Participation'].apply(clean_string)
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0     20.850
# 1   Alabama           1.00     18.9  18.4     19.7     19.4     19.100
# 2    Alaska           0.65     18.7  19.8     20.4     19.9     19.700
# 3   Arizona           0.62     18.6  19.8     20.1     19.8     19.575
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5     19.275

# %% [markdown]
# #### Format the string in `State` using `str.title()` to prepare for merging of DataFrame later

# %%
#Capitalize first letter of string for state
act_2017['State'] = act_2017['State'].apply(str.title)

# %% [markdown]
# #### Rename the columns to lower-case and replace space with underscore

# %%
#Use the pandas rename method by passing in a dictionary of before and after column names
act_2017.rename(columns={'State': 'state',
                         'Participation': 'act_17_participation',
                         'English': 'act_17_english',
                         'Math': 'act_17_math',
                         'Reading': 'act_17_reading',
                         'Science': 'act_17_science',
                         'Composite': 'act_17_composite'
                        }, inplace=True)
act_2017.head()
# Out:
#       state  act_17_participation  act_17_english  act_17_math  \
# 0  National                  0.60            20.3         20.7
# 1   Alabama                  1.00            18.9         18.4
# 2    Alaska                  0.65            18.7         19.8
# 3   Arizona                  0.62            18.6         19.8
# 4  Arkansas                  1.00            18.9         19.0
#
#    act_17_reading  act_17_science  act_17_composite
# 0            21.4            21.0            20.850
# 1            19.7            19.4            19.100
# 2            20.4            19.9            19.700
# 3            20.1            19.8            19.575
# 4            19.7            19.5            19.275

# %% [markdown]
# #### Check for duplicated rows and remove them as necessary

# %%
#Filter the rows which are duplicated
act_2017[act_2017.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, act_17_participation, act_17_english, act_17_math, act_17_reading, act_17_science, act_17_composite]
# Index: []

# %% [markdown]
# #### Data Cleaning completed for `act_2017`

# %%
act_2017.head()
# Out:
#       state  act_17_participation  act_17_english  act_17_math  \
# 0  National                  0.60            20.3         20.7
# 1   Alabama                  1.00            18.9         18.4
# 2    Alaska                  0.65            18.7         19.8
# 3   Arizona                  0.62            18.6         19.8
# 4  Arkansas                  1.00            18.9         19.0
#
#    act_17_reading  act_17_science  act_17_composite
# 0            21.4            21.0            20.850
# 1            19.7            19.4            19.100
# 2            20.4            19.9            19.700
# 3            20.1            19.8            19.575
# 4            19.7            19.5            19.275

# %% [markdown]
# ### Data Cleaning for `act_2018`

# %% [markdown]
# #### Inspect the data for `act_2018`

# %%
# First 5 rows of the act_2018 DataFrame
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %% [markdown]
# #### Inspect the dtype and checking for null values on `act_2018`

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# **Key Observations:**
#
# 1. No null values
# 2. `Participation` dtype should be in float rather than object

# %% [markdown]
# #### Identify rows with errors in `act_2018`

# %%
# Identifying rows with errors
act_2018[(act_2018['Composite']<0)|(act_2018['Composite']>36)]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []

# %% [markdown]
# **Key Observation:**
#
# 1. All scores for `Composite` are within the normal range of 0 to 36

# %% [markdown]
# #### Change values in `Participation` to float between 0 and 1

# %%
# Use the clean_string function defined above on the act_2018['Participation'] column using .apply
act_2018['Participation'] = act_2018['Participation'].apply(clean_string)
act_2018.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %% [markdown]
# #### Format the string in `State` using `str.title()` to prepare for merging of DataFrame later

# %%
#Capitalize first letter of string for state
act_2018['State'] = act_2018['State'].apply(str.title)

# %% [markdown]
# #### Rename the columns to lower-case and replace space with underscore

# %%
#Use the pandas rename method by passing in a dictionary of before and after column names
act_2018.rename(columns={'State': 'state',
                         'Participation': 'act_18_participation',
                         'Composite': 'act_18_composite'
                        }, inplace=True)
act_2018.head()
# Out:
#         state  act_18_participation  act_18_composite
# 0     Alabama                  1.00              19.1
# 1      Alaska                  0.33              20.8
# 2     Arizona                  0.66              19.2
# 3    Arkansas                  1.00              19.4
# 4  California                  0.27              22.7

# %% [markdown]
# #### Check for duplicated rows and remove them as necessary

# %%
#Filter the rows which are duplicated
act_2018[act_2018.duplicated()]
# Out:
#     state  act_18_participation  act_18_composite
# 20  Maine                  0.07              24.0

# %%
#Delete the duplicated row
act_2018.drop_duplicates(inplace=True)
act_2018
# Out:
#                    state  act_18_participation  act_18_composite
# 0                Alabama                  1.00              19.1
# 1                 Alaska                  0.33              20.8
# 2                Arizona                  0.66              19.2
# 3               Arkansas                  1.00              19.4
# 4             California                  0.27              22.7
# 5               Colorado                  0.30              23.9
# 6            Connecticut                  0.26              25.6
# 7               Delaware                  0.17              23.8
# 8   District Of Columbia                  0.32              23.6
# 9                Florida                  0.66              19.9
# 10               Georgia                  0.53              21.4
# 11                Hawaii                  0.89              18.9
# 12                 Idaho                  0.36              22.3
# ...

# %% [markdown]
# #### Data Cleaning completed for `act_2018`

# %%
act_2018.head()
# Out:
#         state  act_18_participation  act_18_composite
# 0     Alabama                  1.00              19.1
# 1      Alaska                  0.33              20.8
# 2     Arizona                  0.66              19.2
# 3    Arkansas                  1.00              19.4
# 4  California                  0.27              22.7

# %% [markdown]
# ### Merge `sat_2017`, `sat_2018`, `act_2017`, `act_2018` into one DataFrame `act_sat_1718`

# %% [markdown]
# #### Check the dimensions of all 4 dataframes

# %%
print(act_2017.shape, act_2018.shape, sat_2017.shape, sat_2018.shape)
# Out:
# (52, 7) (51, 3) (51, 5) (51, 5)

# %% [markdown]
# #### Merge the dataframes

# %%
#act_2017 has an additional row for National scores. Merge act_2018 and act_2017 on left 
#to remove the row in the merged dataframe  
act_1718 = act_2018.merge(act_2017, how='left', on ='state')

#Merge sat_2018 and sat_2017 on left
sat_1718 = sat_2018.merge(sat_2017, how='left', on ='state')

#Merged DataFrame
act_sat_1718 = act_1718.merge(sat_1718, on='state')

# %%
#Inspect act_sat_1718
act_sat_1718.head()
# Out:
#         state  act_18_participation  act_18_composite  act_17_participation  \
# 0     Alabama                  1.00              19.1                  1.00
# 1      Alaska                  0.33              20.8                  0.65
# 2     Arizona                  0.66              19.2                  0.62
# 3    Arkansas                  1.00              19.4                  1.00
# 4  California                  0.27              22.7                  0.31
#
#    act_17_english  act_17_math  act_17_reading  act_17_science  \
# 0            18.9         18.4            19.7            19.4
# 1            18.7         19.8            20.4            19.9
# 2            18.6         19.8            20.1            19.8
# 3            18.9         19.0            19.7            19.5
# 4            22.5         22.7            23.1            22.2
#
#    act_17_composite  sat_18_participation  sat_18_erw  sat_18_math  \
# ...

# %% [markdown]
# #### Delete `act_17_english`, `act_17_math`, `act_17_reading` and `act_17_science` as there are no corresponding data in the ACT 2018 dataset

# %%
act_sat_1718.drop(columns=['act_17_english', 'act_17_math', 'act_17_reading', 'act_17_science'], inplace=True)

# %% [markdown]
# #### Add a column `state_choice` which categorize which tests is compulsory in the state

# %%
#Create lists of states where ACT is mandatory, SAT is mandatory and where both are mandatory

state_act = ['Alabama', 'Hawaii', 'Kentucky', 'Louisiana', 
             'Mississippi', 'Missouri', 'Montana', 'Nebraska', 
             'Nevada', 'North Carolina', 'South Carolina', 'Utah', 
             'Wisconsin', 'Wyoming']

state_sat = ['Colorado', 'Connecticut', 'Delaware', 
             'District Of Columbia', 'Illinois', 'Maine', 
             'Michigan', 'New Hampshire']

state_both =['Idaho', 'Ohio', 'Tennessee']

# %%
#Define a function categorize_state which return the type of test(s) that are mandatory in the state
def categorize_state(state):
    if state in state_act:
        return 'ACT'
    elif state in state_sat:
        return 'SAT'
    elif state in state_both:
        return 'Both'
    else:
        return 'None'

act_sat_1718['state_choice'] = act_sat_1718['state'].apply(categorize_state)

# %% [markdown]
# #### Cleaned and merged `act_sat_1718` DataFrame created

# %%
act_sat_1718
# Out:
#                    state  act_18_participation  act_18_composite  \
# 0                Alabama                  1.00              19.1
# 1                 Alaska                  0.33              20.8
# 2                Arizona                  0.66              19.2
# 3               Arkansas                  1.00              19.4
# 4             California                  0.27              22.7
# 5               Colorado                  0.30              23.9
# 6            Connecticut                  0.26              25.6
# 7               Delaware                  0.17              23.8
# 8   District Of Columbia                  0.32              23.6
# 9                Florida                  0.66              19.9
# 10               Georgia                  0.53              21.4
# 11                Hawaii                  0.89              18.9
# 12                 Idaho                  0.36              22.3
# ...

# %% [markdown]
# ### Save `act_sat_1718` as csv file

# %%
act_sat_1718.to_csv('../data/act_sat_1718.csv')
act_sat_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   act_18_participation  51 non-null     float64
#  2   act_18_composite      51 non-null     float64
#  3   act_17_participation  51 non-null     float64
#  4   act_17_composite      51 non-null     float64
#  5   sat_18_participation  51 non-null     float64
#  6   sat_18_erw            51 non-null     int64
#  7   sat_18_math           51 non-null     int64
#  8   sat_18_total          51 non-null     int64
#  9   sat_17_participation  51 non-null     float64
#  10  sat_17_erw            51 non-null     int64
#  11  sat_17_math           51 non-null     int64
#  12  sat_17_total          51 non-null     int64
#  13  state_choice          51 non-null     object
# dtypes: float64(6), int64(6), object(2)
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# #### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT and SAT, 2017 and 2018|The name of the State in the United States|
# |act_18_participation|float|ACT 2018|The participation rate of ACT in the state in 2018 (units in floats to two decimal places 0.33 means 33%)|
# |act_18_composite|float|ACT 2018|The average ACT Composite score of the state in 2018. The composite score is derived from the average of the scores for English, Math, Reading and Science. The score ranges from 1 to 36 |
# |act_17_participation|float|ACT 2017|The participation rate of ACT in the state in 2017 (units in floats to two decimal places 0.33 means 33%)|
# |act_17_composite|float|ACT 2017|The average ACT Composite score of the state in 2017. The composite score is derived from the average of the scores for English, Math, Reading and Science. The score ranges from 1 to 36 |
# |sat_18_participation|float|SAT 2018|The participation rate of SAT in the state in 2018 (units in floats to two decimal places 0.33 means 33%)|
# |sat_18_erw|int|SAT 2018|The average SAT Evidence-Based Reading and Writing score of the state in 2018. The score ranges from 200 to 800 |
# |sat_18_math|int|SAT 2018|The average SAT Math score of the state in 2018. The score ranges from 200 to 800 |
# |sat_18_total|int|SAT 2018|The average SAT Total score of the state in 2018. The total score is the sum of the scores for Evidence-Based Reading and Writing and Math. The score ranges from 400 to 1600 |
# |sat_17_participation|float|SAT 2017|The participation rate of SAT in the state in 2017 (units in floats to two decimal places 0.33 means 33%)|
# |sat_17_erw|int|SAT 2017|The average SAT Evidence-Based Reading and Writing score of the state in 2017. The score ranges from 200 to 800 |
# |sat_17_math|int|SAT 2017|The average SAT Math score of the state in 2017. The score ranges from 200 to 800 |
# |sat_17_total|int|SAT 2017|The average SAT Total score of the state in 2017. The total score is the sum of the scores for Evidence-Based Reading and Writing and Math. The score ranges from 400 to 1600 |
# |state_choice|object|External Source|The test chosen by the state as mandatory. 'ACT' means the state has chosen ACT as madatory. 'SAT' means the state has chosen SAT as mandatory. 'Both' means both ACT and SAT are mandatory in the state. 'None' means neither ACT nor SAT are compulsory in the state |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Summary Statistics

# %%
#Summary Statistics of all the columns using .describe()

act_sat_1718.describe().T
# Out:
#                       count         mean        std     min       25%  \
# act_18_participation   51.0     0.617255   0.340371    0.07     0.285
# act_18_composite       51.0    21.496078   2.111583   17.70    19.950
# act_17_participation   51.0     0.652549   0.321408    0.08     0.310
# act_17_composite       51.0    21.397549   2.024199   17.65    19.700
# sat_18_participation   51.0     0.457451   0.373143    0.02     0.045
# sat_18_erw             51.0   563.686275  47.502627  480.00   534.500
# sat_18_math            51.0   556.235294  47.772623  480.00   522.500
# sat_18_total           51.0  1119.921569  94.189138  977.00  1058.000
# sat_17_participation   51.0     0.398039   0.352766    0.02     0.040
# sat_17_erw             51.0   569.117647  45.666901  482.00   533.500
# sat_17_math            51.0   556.882353  47.121395  468.00   523.500
# sat_17_total           51.0  1126.000000  92.487621  950.00  1055.500
#
#                           50%        75%      max
# ...

# %% [markdown]
# ### Create a dict `sd` using dictionary comprehension

# %%
#Set col_name as the iterating variable and as the key in the dict 'sd'

#The iterable is act_sat_1718.columns[act_sat_1718.columns!='state'], which is all the columns 
#excluding the non-numeric column 'state' and 'state_choice'

#Using the function cal_sd calculates the standard deviation of the column 'col_name' 
#and store it as the value in the dict 'sd'

sd = {col_name:cal_sd(act_sat_1718[col_name]) 
      for col_name 
      in act_sat_1718.columns[(act_sat_1718.columns!='state')&
                              (act_sat_1718.columns!='state_choice')]}
sd
# Out:
# {'act_18_participation': 0.33701735820410317,
#  'act_18_composite': 2.090779082141178,
#  'act_17_participation': 0.3182417575123181,
#  'act_17_composite': 2.004255612770629,
#  'sat_18_participation': 0.3694661922353942,
#  'sat_18_erw': 47.03460978357609,
#  'sat_18_math': 47.30194550378352,
#  'sat_18_total': 93.26114360945468,
#  'sat_17_participation': 0.3492907076664507,
#  'sat_17_erw': 45.21697020437866,
#  'sat_17_math': 46.65713364485503,
#  'sat_17_total': 91.57639048421622}

# %% [markdown]
# ### Analysis on Trends

# %% [markdown]
# #### Top and Bottom 10 states based on participation rate for ACT in 2017

# %%
# Top 10 states based on participation rate for ACT in 2017
print(act_sat_1718.loc[:,['state', 
                          'act_17_participation'
                         ]].sort_values('act_17_participation', 
                                        ascending=False).head(10))
# Out:
#              state  act_17_participation
# 0          Alabama                   1.0
# 17        Kentucky                   1.0
# 49       Wisconsin                   1.0
# 44            Utah                   1.0
# 42       Tennessee                   1.0
# 40  South Carolina                   1.0
# 36        Oklahoma                   1.0
# 33  North Carolina                   1.0
# 28          Nevada                   1.0
# 26         Montana                   1.0

# %%
# Bottom 10 states based on participation rate for ACT in 2017
print(act_sat_1718.loc[:,['state', 
                          'act_17_participation'
                         ]].sort_values('act_17_participation', 
                                        ascending=False).tail(10))
# Out:
#             state  act_17_participation
# 21  Massachusetts                  0.29
# 45        Vermont                  0.29
# 46       Virginia                  0.29
# 47     Washington                  0.29
# 20       Maryland                  0.28
# 38   Pennsylvania                  0.23
# 39   Rhode Island                  0.21
# 7        Delaware                  0.18
# 29  New Hampshire                  0.18
# 19          Maine                  0.08

# %% [markdown]
# **Key Observations:**
# 1. The Top 10 states in term of ACT participation rate in 2017 correlates with the 14 states that require ACT: Alabama, Hawaii, Kentucky, Louisiana, Mississippi, Missouri, Montana, Nebraska, Nevada, North Carolina, South Carolina, Utah, Wisconsin and Wyoming.
#
# 2. The bottom 10 states states in term of ACT participation rate in 2017 includes states that require SAT such as New Hampshire and Delaware. Geographically, most of them are located in the Northeast Region of the United States

# %% [markdown]
# #### Top and Bottom 10 states based on participation rate for ACT in 2018

# %%
# Top 10 states based on participation rate for ACT in 2018
print(act_sat_1718.loc[:,['state', 
                          'act_18_participation'
                         ]].sort_values('act_18_participation', 
                                        ascending=False).head(10))
# Out:
#              state  act_18_participation
# 0          Alabama                   1.0
# 17        Kentucky                   1.0
# 49       Wisconsin                   1.0
# 44            Utah                   1.0
# 42       Tennessee                   1.0
# 40  South Carolina                   1.0
# 36        Oklahoma                   1.0
# 35            Ohio                   1.0
# 33  North Carolina                   1.0
# 28          Nevada                   1.0

# %%
# Bottom 10 states based on participation rate for ACT in 2018
print(act_sat_1718.loc[:,['state', 
                          'act_18_participation'
                         ]].sort_values('act_18_participation', 
                                        ascending=False).tail(10))
# Out:
#             state  act_18_participation
# 21  Massachusetts                  0.25
# 45        Vermont                  0.24
# 46       Virginia                  0.24
# 47     Washington                  0.24
# 22       Michigan                  0.22
# 38   Pennsylvania                  0.20
# 7        Delaware                  0.17
# 29  New Hampshire                  0.16
# 39   Rhode Island                  0.15
# 19          Maine                  0.07

# %% [markdown]
# **Key Observations:**
#
# 1. As with 2017, the Top 10 states in term of ACT participation rate in 2018 correlates with the 14 states that require ACT: Alabama, Hawaii, Kentucky, Louisiana, Mississippi, Missouri, Montana, Nebraska, Nevada, North Carolina, South Carolina, Utah, Wisconsin and Wyoming.
#
# 2. The bottom 10 states states in term of ACT participation rate in 2018 includes states that require SAT such as New Hampshire and Delaware. Geographically, as with in 2017,  most of them are located in the Northeast Region of the United States

# %% [markdown]
# #### Top and Bottom 10 states based on participation rate for SAT in 2017

# %%
# Top 10 states based on participation rate for SAT in 2017
print(act_sat_1718.loc[:,['state', 
                          'sat_17_participation'
                         ]].sort_values('sat_17_participation', 
                                        ascending=False).head(10))
# Out:
#                    state  sat_17_participation
# 8   District Of Columbia                  1.00
# 22              Michigan                  1.00
# 6            Connecticut                  1.00
# 7               Delaware                  1.00
# 29         New Hampshire                  0.96
# 19                 Maine                  0.95
# 12                 Idaho                  0.93
# 9                Florida                  0.83
# 21         Massachusetts                  0.76
# 39          Rhode Island                  0.71

# %%
# Bottom 10 states based on participation rate for SAT in 2017
print(act_sat_1718.loc[:,['state', 
                          'sat_17_participation'
                         ]].sort_values('sat_17_participation', 
                                        ascending=False).tail(10))
# Out:
#            state  sat_17_participation
# 49     Wisconsin                  0.03
# 25      Missouri                  0.03
# 41  South Dakota                  0.03
# 27      Nebraska                  0.03
# 23     Minnesota                  0.03
# 3       Arkansas                  0.03
# 50       Wyoming                  0.03
# 34  North Dakota                  0.02
# 24   Mississippi                  0.02
# 15          Iowa                  0.02

# %% [markdown]
# **Key Observations:**
#
# 1. The Top 10 states in term of SAT participation rate in 2017 correlates with the 8 states that require SAT: Colorado, Connecticut, Delaware, District of Columbia, Illinois, Maine, Michigan and New Hampshire.
#
# 2. The bottom 10 states states in term of SAT participation rate in 2017 includes states that require ACT such as Wisconsin and Missouri. Geographically, most of them are located in the Midwest and South Region of the United States

# %% [markdown]
# #### Top and Bottom 10 states based on participation rate for SAT in 2018

# %%
# Top 10 states based on participation rate for SAT in 2018
print(act_sat_1718.loc[:,['state', 
                          'sat_18_participation'
                         ]].sort_values('sat_18_participation', 
                                        ascending=False).head(10))
# Out:
#                    state  sat_18_participation
# 5               Colorado                  1.00
# 6            Connecticut                  1.00
# 7               Delaware                  1.00
# 22              Michigan                  1.00
# 12                 Idaho                  1.00
# 19                 Maine                  0.99
# 13              Illinois                  0.99
# 39          Rhode Island                  0.97
# 29         New Hampshire                  0.96
# 8   District Of Columbia                  0.92

# %%
# Bottom 10 states based on participation rate for SAT in 2018
print(act_sat_1718.loc[:,['state', 
                          'sat_18_participation'
                         ]].sort_values('sat_18_participation', 
                                        ascending=False).tail(10))
# Out:
#            state  sat_18_participation
# 18     Louisiana                  0.04
# 17      Kentucky                  0.04
# 16        Kansas                  0.04
# 41  South Dakota                  0.03
# 27      Nebraska                  0.03
# 24   Mississippi                  0.03
# 15          Iowa                  0.03
# 49     Wisconsin                  0.03
# 50       Wyoming                  0.03
# 34  North Dakota                  0.02

# %% [markdown]
# **Key Observations:**
#
# 1. As in 2017, the Top 10 states in term of SAT participation rate in 2018 correlates with the 8 states that require SAT: Colorado, Connecticut, Delaware, District of Columbia, Illinois, Maine, Michigan and New Hampshire.
#
# 2. The bottom 10 states states in term of SAT participation rate in 2018 once again includes states that require ACT such as Wisconsin and Nebraska. Geographically, most of them are located in the Midwest and South Region of the United States

# %% [markdown]
# #### Which states that perform the best in ACT (Composite > 23) in 2017 has the best participation rate?

# %%
# Subset 'act_sat_1718' by filtering only states with ACT Composite score > 23, 
# and sort the dataframe by ACT particpation rate 
act_sat_1718.loc[(act_sat_1718['act_17_composite']>=23),
                 ['state', 
                  'act_17_composite', 
                  'act_17_participation'
                 ]
                ].sort_values('act_17_participation', 
                              ascending=False
                             ).head(10)
# Out:
#                    state  act_17_composite  act_17_participation
# 30            New Jersey            23.725                  0.34
# 8   District Of Columbia            24.075                  0.32
# 6            Connecticut            25.075                  0.31
# 32              New York            24.075                  0.31
# 21         Massachusetts            25.325                  0.29
# 22              Michigan            24.025                  0.29
# 45               Vermont            23.500                  0.29
# 46              Virginia            23.725                  0.29
# 20              Maryland            23.600                  0.28
# 38          Pennsylvania            23.575                  0.23

# %% [markdown]
# #### Which states that perform the best in ACT (Composite > 23) in 2018 has the best participation rate?

# %%
# Subset 'act_sat_1718' by filtering only states with ACT Composite score > 23, 
# and sort the dataframe by ACT particpation rate 
act_sat_1718.loc[(act_sat_1718['act_18_composite']>=23),
                 ['state', 
                  'act_18_composite', 
                  'act_18_participation'
                 ]
                ].sort_values('act_18_participation', 
                              ascending=False
                             ).head(10)
# Out:
#                    state  act_18_composite  act_18_participation
# 13              Illinois              23.9                  0.43
# 8   District Of Columbia              23.6                  0.32
# 30            New Jersey              23.7                  0.31
# 5               Colorado              23.9                  0.30
# 32              New York              24.5                  0.27
# 6            Connecticut              25.6                  0.26
# 21         Massachusetts              25.5                  0.25
# 45               Vermont              24.1                  0.24
# 46              Virginia              23.9                  0.24
# 22              Michigan              24.2                  0.22

# %% [markdown]
# **Key Observations:**
#
# 1. Regardless of state requirement, New Jersey, DC, Connecticut  and New York are among the best performing states with the highest ACT participation rate in both 2017 and 2018
#
# 2. ACT should target these states for high achieving students in these states who may want to take more than 1 tests for college admissions

# %% [markdown]
# #### Which states that perform the best in SAT (Total > 1200) in 2017 has the best participation rate?

# %%
# Subset 'act_sat_1718' by filtering only states with SAT Composite score > 1200, 
# and sort the dataframe by ACT particpation rate 
act_sat_1718.loc[(act_sat_1718['sat_17_total']>=1200),
                 ['state', 
                  'sat_17_total', 
                  'sat_17_participation'
                 ]
                ].sort_values('sat_17_participation', 
                              ascending=False
                             ).head(10)
# Out:
#            state  sat_17_total  sat_17_participation
# 5       Colorado          1201                  0.11
# 42     Tennessee          1227                  0.05
# 16        Kansas          1260                  0.04
# 17      Kentucky          1247                  0.04
# 3       Arkansas          1208                  0.03
# 23     Minnesota          1295                  0.03
# 25      Missouri          1271                  0.03
# 27      Nebraska          1254                  0.03
# 41  South Dakota          1215                  0.03
# 44          Utah          1238                  0.03

# %% [markdown]
# #### Which states that perform the best in SAT (Total > 1200) in 2018 has the best participation rate?

# %%
# Subset 'act_sat_1718' by filtering only states with SAT Composite score > 1200, 
# and sort the dataframe by ACT particpation rate 
act_sat_1718.loc[(act_sat_1718['sat_18_total']>=1200),
                 ['state', 
                  'sat_18_total', 
                  'sat_18_participation'
                 ]
                ].sort_values('sat_18_participation', 
                              ascending=False
                             ).head(10)
# Out:
#            state  sat_18_total  sat_18_participation
# 42     Tennessee          1231                  0.06
# 16        Kansas          1264                  0.04
# 17      Kentucky          1248                  0.04
# 18     Louisiana          1210                  0.04
# 23     Minnesota          1298                  0.04
# 25      Missouri          1262                  0.04
# 15          Iowa          1265                  0.03
# 24   Mississippi          1236                  0.03
# 27      Nebraska          1252                  0.03
# 41  South Dakota          1240                  0.03

# %% [markdown]
# **Key Observations:**
#
# 1. Regardless of state requirement, Tennessee, Kansas and Kentucky are among the best performing states with the highest SAT participation rate in both 2017 and 2018
#
# 2. SAT participation rate in high performing states is much lower than that of ACT.

# %% [markdown]
# #### Which states where ACT is required has the highest SAT participation rate in 2017?

# %%
#Create lists of states where ACT is mandatory, SAT is mandatory and where both are mandatory

state_act = ['Alabama', 'Hawaii', 'Kentucky', 'Louisiana', 
             'Mississippi', 'Missouri', 'Montana', 'Nebraska', 
             'Nevada', 'North Carolina', 'South Carolina', 'Utah', 
             'Wisconsin', 'Wyoming']

state_sat = ['Colorado', 'Connecticut', 'Delaware', 
             'District Of Columbia', 'Illinois', 'Maine', 
             'Michigan', 'New Hampshire']

state_both =['Idaho', 'Ohio', 'Tennessee']

# %%
# Subset 'act_sat_1718' by filtering only states where ACT is required, and the ACT 2017, 
#SAT 2017 participation and SAT 2018 Total score columns 
# and sort the dataframe by ACT participation rate 
act_sat_1718.loc[act_sat_1718['state'].isin(state_act),['state', 
                                                        'act_17_participation', 
                                                        'sat_17_participation', 
                                                        'sat_17_total'
                                                       ]
                ].sort_values(by='sat_17_participation', 
                              ascending=False).tail(10)
# Out:
#           state  act_17_participation  sat_17_participation  sat_17_total
# 26      Montana                  1.00                  0.10          1196
# 0       Alabama                  1.00                  0.05          1165
# 17     Kentucky                  1.00                  0.04          1247
# 18    Louisiana                  1.00                  0.04          1197
# 25     Missouri                  1.00                  0.03          1271
# 27     Nebraska                  0.84                  0.03          1254
# 44         Utah                  1.00                  0.03          1238
# 49    Wisconsin                  1.00                  0.03          1291
# 50      Wyoming                  1.00                  0.03          1230
# 24  Mississippi                  1.00                  0.02          1241

# %% [markdown]
# #### Which states where ACT is required has the highest SAT participation rate in 2018?

# %%
# Subset 'act_sat_1718' by filtering only states where ACT is required, and the ACT 2018, 
#SAT 2018 participation and SAT 2018 Total score columns 
# and sort the dataframe by ACT participation rate 
act_sat_1718.loc[act_sat_1718['state'].isin(state_act),['state', 
                                                        'act_18_participation', 
                                                        'sat_18_participation', 
                                                        'sat_18_total'
                                                       ]
                ].sort_values(by='sat_18_participation', 
                              ascending=False).tail(10)
# Out:
#           state  act_18_participation  sat_18_participation  sat_18_total
# 26      Montana                   1.0                  0.10          1198
# 0       Alabama                   1.0                  0.06          1166
# 17     Kentucky                   1.0                  0.04          1248
# 18    Louisiana                   1.0                  0.04          1210
# 25     Missouri                   1.0                  0.04          1262
# 44         Utah                   1.0                  0.04          1010
# 24  Mississippi                   1.0                  0.03          1236
# 27     Nebraska                   1.0                  0.03          1252
# 49    Wisconsin                   1.0                  0.03          1294
# 50      Wyoming                   1.0                  0.03          1258

# %% [markdown]
# **Key Observations:**
#
# 1. Hawaii, North Carolina and South Carolina are ACT compulsory states where there is high participation in SAT in both 2017 and 2018
#
# 2. SAT should focus their resources on expanding their market share in these states

# %% [markdown]
# #### Which states where SAT is required has the highest ACT participation rate in 2017?

# %%
# Subset 'act_sat_1718' by filtering only states where SAT is required, and the ACT 2017, 
#SAT 2017 participation and SAT 2017 Total score columns 
# and sort the dataframe by ACT participation rate 
act_sat_1718.loc[act_sat_1718['state'].isin(state_sat),['state', 
                                                        'sat_17_participation', 
                                                        'act_17_participation', 
                                                        'act_17_composite'
                                                       ]
                ].sort_values(by='act_17_participation', 
                                  ascending=False).head(10)
# Out:
#                    state  sat_17_participation  act_17_participation  \
# 5               Colorado                  0.11                  1.00
# 13              Illinois                  0.09                  0.93
# 8   District Of Columbia                  1.00                  0.32
# 6            Connecticut                  1.00                  0.31
# 22              Michigan                  1.00                  0.29
# 7               Delaware                  1.00                  0.18
# 29         New Hampshire                  0.96                  0.18
# 19                 Maine                  0.95                  0.08
#
#     act_17_composite
# 5             20.625
# 13            21.275
# 8             24.075
# 6             25.075
# 22            24.025
# 7             23.975
# 29            25.350
# 19            24.175

# %% [markdown]
# #### Which states where SAT is required has the highest ACT participation rate in 2018?

# %%
# Subset 'act_sat_1718' by filtering only states where SAT is required, and the ACT 2018, 
#SAT 2018 participation and SAT 2018 Total score columns 
# and sort the dataframe by ACT participation rate 
act_sat_1718.loc[act_sat_1718['state'].isin(state_sat),['state', 
                                                        'sat_18_participation', 
                                                        'act_18_participation', 
                                                        'act_18_composite'
                                                       ]
                ].sort_values(by='act_18_participation', 
                                  ascending=False).head(10)
# Out:
#                    state  sat_18_participation  act_18_participation  \
# 13              Illinois                  0.99                  0.43
# 8   District Of Columbia                  0.92                  0.32
# 5               Colorado                  1.00                  0.30
# 6            Connecticut                  1.00                  0.26
# 22              Michigan                  1.00                  0.22
# 7               Delaware                  1.00                  0.17
# 29         New Hampshire                  0.96                  0.16
# 19                 Maine                  0.99                  0.07
#
#     act_18_composite
# 13              23.9
# 8               23.6
# 5               23.9
# 6               25.6
# 22              24.2
# 7               23.8
# 29              25.1
# 19              24.0

# %% [markdown]
# **Key Observations:**
#
# 1. Colorado and Illinois SAT participation rate increased from about 10% in 2017 to almost 100% in 2018. Given that Colorado and Illinois only switched to mandatory SAT in the 2016-2017 school, this sudden increase in participation reflects the year of transition([*source*](https://blog.prepscholar.com/which-states-require-the-sat)).
#
# 2. SAT should focus their resources on DC, Connecticut and Michigan to expand their market share in these states.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### Correlation between all numeric features

# %%
# Create a heatmap to visualize the correlation between all numeric features

corr = act_sat_1718.corr()
plt.figure(figsize=(12,12))

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# plot the heatmap
sns.heatmap(corr, mask=mask, annot=True, vmin=-1, vmax=1, center= 0, cmap='coolwarm')
plt.title('Correlation Between Numeric Features');

# %% [markdown]
# Key Observations:
#
# - Performance is negatively correlated with Participation in general for both ACT and SAT in both 2017 and 2018

# %% [markdown]
# #### Histogram of all features

# %%
sns.set()
fig, ax = plt.subplots(3, 4)
fig.set_size_inches([15,9])
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.95,
                    top=0.95,
                    wspace=0.5,
                    hspace=0.5)

#Plot all features in a 3 X 4 grid
for row in range(3):
    for col in range(4):
        # use row and col to map to the column index using the formula 4*(row-1)+col+3+2
        ax[row,col].hist(act_sat_1718[act_sat_1718.columns[4*(row-1)+col+3+2]], bins=7) 
        ax[row,col].set_xlabel(act_sat_1718.columns[4*(row-1)+col+3+2])
        ax[row,col].set_ylabel("# of observations")
plt.suptitle('Histogram of All Features');

# %% [markdown]
# **Key Observation**
#
# Generally, the features do not look normally distributed. Some features such as ACT Composite Score in 2018 is bimodal.

# %% [markdown]
# #### Boxplot of Participation Rate for both ACT and SAT in 2017 and 2018

# %%
fig, ax = plt.subplots()
fig.set_size_inches([10,5])


_ = sns.boxplot(x='variable', y='value', data=pd.melt(act_sat_1718[['act_17_participation',
                                                                    'act_18_participation',
                                                                    'sat_17_participation',
                                                                    'sat_18_participation']]))
_.set_xlabel('Test (Year)')
_.set_xticklabels(['ACT (2017)', 'ACT (2018)', 'SAT (2017)', 'SAT (2018)'])
_.set_ylabel('Participation Rates')
plt.title('Boxplot of Participation Rates for SAT and ACT in 2017 and 2018');

# %% [markdown]
# **Key Observations:**
# 1. The median participation for ACT is higher than SAT for both 2017 and 2018
#
# 2. There were no outlying data for all 4 features

# %% [markdown]
# #### Boxplot of ACT Composite Score in 2017 and 2018

# %%
fig, ax = plt.subplots()
fig.set_size_inches([10,5])


_ = sns.boxplot(x='variable', y='value', data=pd.melt(act_sat_1718[['act_17_composite',
                                                                    'act_18_composite']]))
_.set_xlabel('Test (Year)')
_.set_xticklabels(['ACT (2017)', 'ACT (2018)'])
_.set_ylabel('Participation Rates')
plt.title('Boxplot of ACT Composite Score in 2017 and 2018');

# %% [markdown]
# #### Boxplot of SAT Total Score in 2017 and 2018

# %%
fig, ax = plt.subplots()
fig.set_size_inches([10,5])


_ = sns.boxplot(x='variable', y='value', data=pd.melt(act_sat_1718[['sat_17_total',
                                                                    'sat_18_total']]))

_.set_xlabel('Test (Year)')
_.set_xticklabels(['SAT (2017)', 'SAT (2018)'])
_.set_ylabel('Participation Rates')
plt.title('Boxplot of SAT Total Score in 2017 and 2018');

# %% [markdown]
# **Key Observations:**
#
# 1. Distribution of both SAT and ACT participation rates are consistent between 2017 and 2018

# %% [markdown]
# #### Which states where SAT is mandatory has the highest participation rate for ACT in 2017?

# %%
# Plot a scatterplot using seaborn relplot.
sns.set_context('talk')
ax = sns.relplot(x='act_17_composite',
                 y='act_17_participation',
                 data=act_sat_1718,
                 kind='scatter', 
                 height=8, 
                 aspect=10/5,
                 hue='state_choice',   
                 style='state_choice',
                 palette=['grey', 'grey', 'blue', 'grey'], #only SAT-mandatory states markers are in blue
                 alpha=0.7
                )

ax.set(xlabel='ACT Composite Score',
       ylabel='ACT Participation Rate x100(%)',
       title='ACT State Performance vs ACT Participation 2017 ');

#Label all states on the scatterplot where SAT is compulsory
for state in state_sat:
    plt.text(x= act_sat_1718['act_17_composite'][act_sat_1718['state']==state],
             y= act_sat_1718['act_17_participation'][act_sat_1718['state']==state],
             s=state,
             fontdict=dict(color='black',
                           alpha=0.5,
                           size=16));

# %% [markdown]
# #### Which states where SAT is mandatory has the highest participation rate for ACT in 2018?

# %%
sns.set_context('talk')
ax = sns.relplot(x='act_18_composite',
                 y='act_18_participation',
                 data=act_sat_1718,
                 kind='scatter', 
                 height=8, 
                 aspect=10/5,
                 hue='state_choice',
                 style='state_choice',
                 palette=['grey', 'grey', 'blue', 'grey'], #only SAT-mandatory states markers are in blue
                 alpha=0.7
                )

ax.set(xlabel='ACT Composite Score',
       ylabel='ACT Participation Rate x100(%)',
       title='ACT State Performance vs ACT Participation 2018 ');

#Label all states on the scatterplot where SAT is compulsory
for state in state_sat:
    plt.text(x= act_sat_1718['act_18_composite'][act_sat_1718['state']==state],
             y= act_sat_1718['act_18_participation'][act_sat_1718['state']==state],
             s=state,
             fontdict=dict(color='black',
                           alpha=0.5,
                           size=16));

# %% [markdown]
# #### Which states where neither test is required has the lowest participation rate (< 0.2) for ACT in 2018?

# %%
sns.set_context('talk')
ax = sns.relplot(x='act_18_composite',
                 y='act_18_participation',
                 data=act_sat_1718,
                 kind='scatter', 
                 height=8, 
                 aspect=10/5,
                 hue='state_choice',
                 style='state_choice',
                 palette=['grey', 'orange', 'grey', 'grey'], #only states markers with no test requirement
                 alpha=0.7,                                  # in orange 
                )

ax.set(xlabel='ACT Composite Score',
       ylabel='ACT Participation Rate x100(%)',
       title='ACT State Performance vs ACT Participation 2018 ');


#Label all states on the scatterplot where neither test are compulsory and ACT participation in 2018 is < 0.2
for state in act_sat_1718['state'][(act_sat_1718['state_choice']=='None')&
                                   (act_sat_1718['act_18_participation']<=0.2)]:
    plt.text(x= act_sat_1718['act_18_composite'][act_sat_1718['state']==state],
             y= act_sat_1718['act_18_participation'][act_sat_1718['state']==state],
             s=state,
             fontdict=dict(color='black',
                           alpha=0.5,
                           size=16));
    
    #(act_sat_1718['act_18_participation']<=0.4) & (act_sat_1718['state_choice']=='Both'))

# %% [markdown]
# #### Which states where ACT is mandatory has the highest participation rate for SAT in 2017?

# %%
sns.set_context('talk')
ax = sns.relplot(x='sat_17_total',
                 y='sat_17_participation',
                 data=act_sat_1718,
                 kind='scatter', 
                 height=8, 
                 aspect=10/5,
                 hue='state_choice',
                 style='state_choice',
                 palette=['red', 'grey', 'grey', 'grey'], #only ACT-mandatory states markers are in red
                 alpha=0.7
                )

ax.set(xlabel='SAT Total Score',
       ylabel='SAT Participation Rate x100(%)',
       title='SAT State Performance vs SAT Participation 2017');

#Label all states on the scatterplot where ACT is compulsory
for state in state_act:
    plt.text(x= act_sat_1718['sat_17_total'][act_sat_1718['state']==state],
             y= act_sat_1718['sat_17_participation'][act_sat_1718['state']==state],
             s=state,
             fontdict=dict(color='black',
                           alpha=0.5,
                           size=16));

# %% [markdown]
# #### Which states where ACT is mandatory has the highest participation rate for SAT in 2018?

# %%
sns.set_context('poster')
ax = sns.relplot(x='sat_18_total',
                 y='sat_18_participation',
                 data=act_sat_1718,
                 kind='scatter', 
                 height=8, 
                 aspect=10/5,
                 hue='state_choice',
                 style='state_choice',
                 palette=['red', 'grey', 'grey', 'grey'], #only ACT-mandatory states markers are in red
                 alpha=0.7
                )

ax.set(xlabel='SAT Total Score',
       ylabel='SAT Participation Rate x100(%)',
       title='SAT State Performance vs SAT Participation 2018');

#Label all states on the scatterplot where ACT is compulsory
for state in state_act:
    plt.text(x= act_sat_1718['sat_18_total'][act_sat_1718['state']==state],
             y= act_sat_1718['sat_18_participation'][act_sat_1718['state']==state],
             s=state,
             fontdict=dict(color='black',
                           alpha=0.5,
                           size=16));

# %% [markdown]
# #### Which states that perform the best in ACT (Composite > 23) in 2018 has the best participation rate?

# %%
# Subset 'act_sat_1718' by filtering only states with ACT Composite score > 23, 
# and sort the dataframe by ACT participation rate 
df =act_sat_1718.loc[(act_sat_1718['act_18_composite']>=23),
                 ['state', 
                  'act_18_composite', 
                  'act_18_participation'
                 ]
                ].sort_values('act_18_participation', 
                              ascending=False)

# Plot the bar chart                              
sns.set_context('talk')
ax=sns.catplot(x='act_18_participation', 
            y='state', 
            data=df,
            kind='bar',
            height=10, 
            aspect=5/7,
           )

# Set the labels and title   
ax.set(xlabel='ACT Participation Rate x100(%)',
       title='ACT Participation Rate in 2018 for States with ACT Composite Score > 23 ');

# %% [markdown]
# **Key Observations:**
#
# 1. The Participation Rate and Performance of both ACT and SAT in 2018 are negatively correlated
#
# 2. Some plausible reasons are as follows:
#
# - States with high participation rate would include students of a range of ability, thereby having a lower average performance
#
# - States with low participation rate for a particular test have usually made the other test compulsory. Only the high achieving students are taking the non-compulsory test in their state. This has the possible effect of having states with low participation having higher performance.
#
# 3. Colorado and Illinois SAT participation rate increased from about 10% in 2017 to almost 100% in 2018. Given that Colorado and Illinois only switched to mandatory SAT in the 2016-2017 school, this sudden increase in participation reflects the year of transition from ACT to SAT([*source*](https://blog.prepscholar.com/which-states-require-the-sat)).
#
# 4. The scatterplot where the states with no test requirement that had the least participation (< 20%) in ACT shows that effort needs to be stepped up to increase the Rhode Island and Pennsylvania participation. This is pertinent as it shows that ACT is not favoured in these states where students are free to choose the test they wish to take.
#
# 5. States with more academically inclined student should be assigned resources to increase the the participation. The bar chart shows that Illinois, DC and New Jersey are among the states that perform the best in ACT (Composite > 23) in 2018.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ### Key Observations and Conclusions
#
# The following were the key observations made from the given data:
#
# 1. The choice of mandatory test in the state leads to high participation rate of the test. This is not surprising given that the cost of a test that is made mandatory is also most likely to be covered by the state government, which therefore access to low-income students.
#
# 2. The states that has the least participation rate in ACT tends to be from the Northeast Region of the United States, whereas states from the Midwest and the South tend to have the least participation rate in SAT. Again, this may be related to the state's choice of mandatory test.
#
# 3. New Jersey, DC, Connecticut and New York performed best for ACT. Tennessee, Kansas and Kentucky leads in performance for SAT.
#
# 4. Colorado and Illinois SAT participation rate experienced a sharp increase from about 10% in 2017 to almost 100% in 2018. Given that Colorado and Illinois only switched to mandatory SAT in the 2016-2017 school year, this sudden increase in participation reflects the year of transition.
#
# 5. Performance is negatively correlated with Participation in general for both ACT and SAT in both 2017 and 2018. Some plausible reasons are as follows:
#
# - States with high participation rate would include students of a range of ability, thereby lowering the average performance.
#
# - Only a small number of more academically students are taking the non-compulsory test in their state. This has the possible effect of having states with low participation having higher performance.
#
# 6. Distribution of both SAT and ACT participation rates are consistent between 2017 and 2018.
#
# ### Recommendations
#
# The following are suggested follow-up actions for ACT:
#
# 1. Despite some states making certain SAT mandatory, it is obvious that there is strong demand for the ACT in certain states. This may stem from the fact that some students, especially the ones who are more academically inclined wishes to enroll in both tests to expand their range of college options.   The ACT should analyse further the reasons for such high participation rate for their test and seek to duplicate the conditions in states where the participation rate is lower.
#
#
# 2. The ACT should devote more resources to increase the current ACT participation rate (< 20%) of the following states where neither tests are required:
# - Pennsylvania
# - Rhode Island
#
#
# 3. The ACT should also assign resources to states to increase ACT participation where academically inclined students are more likely to take more than one tests such as Illinois, DC and New Jersey.
